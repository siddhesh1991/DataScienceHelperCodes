# %% [markdown]
# # Program to get the content of the page for Apps in iTunes

# %% [markdown]
# # Load libraries...

# %%
import json
import requests
import yaml # to parse json file without unicode. Refer http://stackoverflow.com/questions/956867/how-to-get-string-objects-instead-of-unicode-ones-from-json-in-python
import numpy as np
import pymongo
import pprint

# %% [markdown]
# # Connect to MongoDB, create a DB and a Collection

# %%
#client.drop_database('apple')

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db=client.apple  # database name apple and collection name app
collection = db.apps

# %% [markdown]
# # List all the app Ids for which we want to fetch the content

# %%
# put all the app ids into an array
app_id = np.array(['1044202386','298844386','542511686','756904853','317469184','302920553','331177714',
                 '321327691','284035177','324684580','512939461','642821482','403858572','434613896',
                  '389781154','441813332','1017492454','407558537','283646709','445170859','296581815','505911015',
                '348177453','333177961','288429040','284882215','372513032','310633997','456034437','588647136'])
# Initializing an empty list
json_list =[]

# %% [markdown]
# # Loop through these four steps below for each App Id
#  1) Get the app's page content.
#
#  2) Parse it into json object
#
#  3) Clean some unwanted data.
#
#  4) Insert the json object into the MongoDb

# %%
for ii in app_id:
    link = 'https://itunes.apple.com/lookup?id='+str(ii)
    #Copying the content
    resp = requests.get(link)
    
    # parse into json object without unicode
    d = yaml.safe_load(resp.content)
    
    # delete unnecessary content. For example some Urls
    key_to_remove = ('ipadScreenshotUrls','description','artistViewUrl','artworkUrl100','artworkUrl512',
                     'screenshotUrls','artworkUrl60','isGameCenterEnabled','isVppDeviceBasedLicensingEnabled',
                     'releaseNotes','supportedDevices','languageCodesISO2A','trackViewUrl','bundleId')
    for key in key_to_remove:
        del d["results"][0][key]
    #del d["results"][0]["screenshotUrls"]

    # Inserting the Id to json object. currently it is not there
    d["results"][0]['Id']= ii
    
    # append all the json objects in a list
    # json_list.append(d["results"][0])
    collection.insert_one(d["results"][0])

# %%
#json_list
#Writing the description to a file
#output_file = open("C:/ADMS/Project/apps.json","w")
#output_file.writelines( "%s\n" % item for item in json_list)
#output_file.close()
json_list

# %% [markdown]
# # Lets explore...

# %%
# Number of Document
collection.count()
# Out:
# 30

# %%
# Aggregate function
pipe =  [
            {"$group":{"_id":"$primaryGenreName","count":{"$sum":1}}}
        ]
list(collection.aggregate(pipe))
# Out:
# [{u'_id': u'Social Networking', u'count': 5},
#  {u'_id': u'Games', u'count': 4},
#  {u'_id': u'Business', u'count': 3},
#  {u'_id': u'Food & Drink', u'count': 5},
#  {u'_id': u'Sports', u'count': 4},
#  {u'_id': u'Music', u'count': 4},
#  {u'_id': u'Finance', u'count': 5}]

# %%
collection.find_one()
# Out:
# {u'Id': u'1044202386',
#  u'_id': ObjectId('58430c2f4d992d1aec031ba5'),
#  u'advisories': [],
#  u'appletvScreenshotUrls': [],
#  u'artistId': 344048912,
#  u'artistName': u'Games2win',
#  u'averageUserRating': 5.0,
#  u'averageUserRatingForCurrentVersion': 4.5,
#  u'contentAdvisoryRating': u'4+',
#  u'currency': u'USD',
#  u'currentVersionReleaseDate': u'2016-04-28T02:29:29Z',
#  u'features': [u'iosUniversal'],
#  u'fileSizeBytes': u'360538112',
#  u'formattedPrice': u'Free',
#  u'genreIds': [u'6014', u'6016', u'7009', u'7012'],
#  u'genres': [u'Games', u'Entertainment', u'Family', u'Puzzle'],
#  u'kind': u'software',
#  u'minimumOsVersion': u'7.0',
#  u'price': 0.0,
#  u'primaryGenreId': 6014,
#  u'primaryGenreName': u'Games',
#  u'releaseDate': u'2015-12-03T08:14:08Z',
#  u'sellerName': u'Games2win India',
#  u'sellerUrl': u'http://www.games2win.com/itunes/index.asp',
#  u'trackCensoredName': u'Miranda Sings vs Haters',
#  u'trackContentRating': u'4+',
#  u'trackId': 1044202386,
#  u'trackName': u'Miranda Sings vs Haters',
#  u'userRatingCount': 2096,
#  u'userRatingCountForCurrentVersion': 119,
#  u'version': u'1.1',
#  u'wrapperType': u'software'}

# %%
# Projection
pprint.pprint(list(collection.find(
    {},{"artistName":1,"primaryGenreName":1,"_id":0}
).sort("primaryGenreName",1)))

# %%
# Projection
pprint.pprint(list(collection.find(
    {},{"artistName":1,"averageUserRating":1,"_id":0}
).sort("averageUserRating",-1)))
# Out:
# [{u'artistName': u'Games2win', u'averageUserRating': 5.0},
#  {u'artistName': u'GrubHub.com', u'averageUserRating': 4.5},
#  {u'artistName': u'Spotify Ltd.', u'averageUserRating': 4.5},
#  {u'artistName': u'Kiloo', u'averageUserRating': 4.5},
#  {u'artistName': u'Halfbrick Studios', u'averageUserRating': 4.5},
#  {u'artistName': u'Saavn', u'averageUserRating': 4.5},
#  {u'artistName': u'Capital One', u'averageUserRating': 4.5},
#  {u'artistName': u'OpenTable, Inc.', u'averageUserRating': 4.5},
#  {u'artistName': u'TangoMe, Inc.', u'averageUserRating': 4.5},
#  {u'artistName': u'Quora, Inc.', u'averageUserRating': 4.5},
#  {u'artistName': u'Cisco', u'averageUserRating': 4.0},
#  {u'artistName': u'FIFA', u'averageUserRating': 4.0},
#  {u'artistName': u'Starbucks Coffee Company', u'averageUserRating': 4.0},
#  {u'artistName': u'Pandora Media, Inc.', u'averageUserRating': 4.0},
#  {u'artistName': u'Rovio Entertainment Ltd', u'averageUserRating': 4.0},
#  {u'artistName': u'PayPal, Inc.', u'averageUserRating': 4.0},
#  {u'artistName': u'Visible Market Inc.', u'averageUserRating': 4.0},
#  {u'artistName': u'PayPal, Inc.', u'averageUserRating': 4.0},
#  {u'artistName': u'WhatsApp Inc.', u'averageUserRating': 4.0},
#  {u'artistName': u'ESPN', u'averageUserRating': 3.5},
#  {u'artistName': u'Google, Inc.', u'averageUserRating': 3.5},
#  {u'artistName': u'FOX News Digital', u'averageUserRating': 3.5},
#  {u'artistName': u'LinkedIn Corporation', u'averageUserRating': 3.5},
#  {u'artistName': u'Facebook, Inc.', u'averageUserRating': 3.5},
#  {u'artistName': u'Fidelity Investments', u'averageUserRating': 3.0},
#  {u'artistName': u'NBCUniversal Media, LLC', u'averageUserRating': 2.5},
#  {u'artistName': u'Happy Hour Finder, Inc', u'averageUserRating': 2.5},
#  {u'artistName': u'Zomato Media Pvt. Ltd.', u'averageUserRating': 2.5},
#  {u'artistName': u'NFL Enterprises LLC', u'averageUserRating': 2.5},
#  {u'artistName': u'Forbes Media LLC', u'averageUserRating': 2.5}]

# %%
# Query with single key
pprint.pprint(list(collection.find(
{"Id":"1017492454"}
)))

# %%
# Query with multiple key
pprint.pprint(list(collection.find(
{"primaryGenreName":"Sports", "averageUserRating" : 4.0}, {"artistName":1,"_id":0}
)))

# %%
# Query with in inequalities
pprint.pprint(list(collection.find(
    {"averageUserRating":{"$gte":4.5}}, {"artistName":1,"_id":0}
)))

# %%
pprint.pprint(list(collection.find(
    {
        "$or":[
        {"primaryGenreName":"Sports"},
        {"averageUserRating" : 4.5}
        ]
    }
)))
# Out:
# [{u'Id': u'542511686',
#   u'_id': ObjectId('58430c2f4d992d1aec031ba7'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 303544359,
#   u'artistName': u'NBCUniversal Media, LLC',
#   u'averageUserRating': 2.5,
#   u'averageUserRatingForCurrentVersion': 2.5,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-10-10T20:55:29Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'111559680',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6004', u'6016'],
#   u'genres': [u'Sports', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'7.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6004,
#   u'primaryGenreName': u'Sports',
#   u'releaseDate': u'2012-07-12T12:43:45Z',
#   u'sellerName': u'NBCUniversal Media, LLC',
#   u'trackCensoredName': u'NBC Sports',
#   u'trackContentRating': u'4+',
#   u'trackId': 542511686,
#   u'trackName': u'NBC Sports',
#   u'userRatingCount': 44950,
#   u'userRatingCountForCurrentVersion': 917,
#   u'version': u'4.8.1',
#   u'wrapperType': u'software'},
#  {u'Id': u'756904853',
#   u'_id': ObjectId('58430c2f4d992d1aec031ba8'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 375974040,
#   u'artistName': u'FIFA',
#   u'averageUserRating': 4.0,
#   u'averageUserRatingForCurrentVersion': 2.0,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-09-05T19:17:40Z',
#   u'features': [],
#   u'fileSizeBytes': u'61757440',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6004', u'6016'],
#   u'genres': [u'Sports', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'7.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6004,
#   u'primaryGenreName': u'Sports',
#   u'releaseDate': u'2013-11-27T15:19:04Z',
#   u'sellerName': u'Federation Internationale de Football Association',
#   u'sellerUrl': u'http://www.fifa.com',
#   u'trackCensoredName': u'FIFA Official App',
#   u'trackContentRating': u'4+',
#   u'trackId': 756904853,
#   u'trackName': u'FIFA Official App',
#   u'userRatingCount': 1338,
#   u'userRatingCountForCurrentVersion': 12,
#   u'version': u'3.3.1',
#   u'wrapperType': u'software'},
#  {u'Id': u'317469184',
#   u'_id': ObjectId('58430c2f4d992d1aec031ba9'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 317469187,
#   u'artistName': u'ESPN',
#   u'averageUserRating': 3.5,
#   u'averageUserRatingForCurrentVersion': 1.5,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-12-01T13:50:53Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'51850240',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6004', u'6016'],
#   u'genres': [u'Sports', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'9.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6004,
#   u'primaryGenreName': u'Sports',
#   u'releaseDate': u'2009-06-02T07:00:00Z',
#   u'sellerName': u'ESPN Inc.',
#   u'sellerUrl': u'http://www.espn.com',
#   u'trackCensoredName': u'ESPN - Get scores, news, and watch live sports',
#   u'trackContentRating': u'4+',
#   u'trackId': 317469184,
#   u'trackName': u'ESPN - Get scores, news, and watch live sports',
#   u'userRatingCount': 288734,
#   u'userRatingCountForCurrentVersion': 61,
#   u'version': u'5.4',
#   u'wrapperType': u'software'},
#  {u'Id': u'302920553',
#   u'_id': ObjectId('58430c2f4d992d1aec031baa'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 302920556,
#   u'artistName': u'GrubHub.com',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.0,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-21T15:38:06Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'126106624',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6023', u'6003'],
#   u'genres': [u'Food & Drink', u'Travel'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6023,
#   u'primaryGenreName': u'Food & Drink',
#   u'releaseDate': u'2009-02-04T03:37:30Z',
#   u'sellerName': u'GrubHub Inc',
#   u'sellerUrl': u'http://www.grubhub.com',
#   u'trackCensoredName': u'Grubhub Food Delivery & Takeout',
#   u'trackContentRating': u'4+',
#   u'trackId': 302920553,
#   u'trackName': u'Grubhub Food Delivery & Takeout',
#   u'userRatingCount': 32435,
#   u'userRatingCountForCurrentVersion': 327,
#   u'version': u'3.16.2',
#   u'wrapperType': u'software'},
#  {u'Id': u'324684580',
#   u'_id': ObjectId('58430c304d992d1aec031bae'),
#   u'advisories': [u'Infrequent/Mild Profanity or Crude Humor',
#                   u'Infrequent/Mild Sexual Content and Nudity',
#                   u'Infrequent/Mild Alcohol, Tobacco, or Drug Use or References',
#                   u'Infrequent/Mild Mature/Suggestive Themes'],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 324684583,
#   u'artistName': u'Spotify Ltd.',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 5.0,
#   u'contentAdvisoryRating': u'12+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-02T10:14:20Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'126201856',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6011', u'6016'],
#   u'genres': [u'Music', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6011,
#   u'primaryGenreName': u'Music',
#   u'releaseDate': u'2011-07-14T11:22:37Z',
#   u'sellerName': u'Spotify',
#   u'sellerUrl': u'http://www.spotify.com/',
#   u'trackCensoredName': u'Spotify Music',
#   u'trackContentRating': u'12+',
#   u'trackId': 324684580,
#   u'trackName': u'Spotify Music',
#   u'userRatingCount': 799088,
#   u'userRatingCountForCurrentVersion': 13850,
#   u'version': u'6.8.0',
#   u'wrapperType': u'software'},
#  {u'Id': u'512939461',
#   u'_id': ObjectId('58430c304d992d1aec031baf'),
#   u'advisories': [u'Infrequent/Mild Cartoon or Fantasy Violence'],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 330629809,
#   u'artistName': u'Kiloo',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.5,
#   u'contentAdvisoryRating': u'9+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-28T22:41:27Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'140802048',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6014', u'7001', u'7003', u'6016'],
#   u'genres': [u'Games', u'Action', u'Arcade', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'7.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6014,
#   u'primaryGenreName': u'Games',
#   u'releaseDate': u'2012-05-24T07:00:00Z',
#   u'sellerName': u'Kiloo',
#   u'sellerUrl': u'http://www.kiloo.com/games',
#   u'trackCensoredName': u'Subway Surfers',
#   u'trackContentRating': u'9+',
#   u'trackId': 512939461,
#   u'trackName': u'Subway Surfers',
#   u'userRatingCount': 687219,
#   u'userRatingCountForCurrentVersion': 516,
#   u'version': u'1.64.1',
#   u'wrapperType': u'software'},
#  {u'Id': u'403858572',
#   u'_id': ObjectId('58430c304d992d1aec031bb1'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 356994313,
#   u'artistName': u'Halfbrick Studios',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.0,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-07T05:51:43Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'139808768',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6014', u'6016', u'7003', u'7001'],
#   u'genres': [u'Games', u'Entertainment', u'Arcade', u'Action'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'7.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6014,
#   u'primaryGenreName': u'Games',
#   u'releaseDate': u'2010-12-20T08:00:00Z',
#   u'sellerName': u'Halfbrick',
#   u'sellerUrl': u'http://fruitninja.com/',
#   u'trackCensoredName': u'Fruit Ninja Free',
#   u'trackContentRating': u'4+',
#   u'trackId': 403858572,
#   u'trackName': u'Fruit Ninja Free',
#   u'userRatingCount': 325082,
#   u'userRatingCountForCurrentVersion': 372,
#   u'version': u'2.4.2',
#   u'wrapperType': u'software'},
#  {u'Id': u'389781154',
#   u'_id': ObjectId('58430c314d992d1aec031bb3'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 389781157,
#   u'artistName': u'NFL Enterprises LLC',
#   u'averageUserRating': 2.5,
#   u'averageUserRatingForCurrentVersion': 4.0,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-16T19:48:23Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'120948736',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6004', u'6016'],
#   u'genres': [u'Sports', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6004,
#   u'primaryGenreName': u'Sports',
#   u'releaseDate': u'2010-09-10T02:13:00Z',
#   u'sellerName': u'NFL Enterprises  LLC',
#   u'sellerUrl': u'http://www.nfl.com/mobile/app',
#   u'trackCensoredName': u'NFL',
#   u'trackContentRating': u'4+',
#   u'trackId': 389781154,
#   u'trackName': u'NFL',
#   u'userRatingCount': 25866,
#   u'userRatingCountForCurrentVersion': 375,
#   u'version': u'12.6.7',
#   u'wrapperType': u'software'},
#  {u'Id': u'441813332',
#   u'_id': ObjectId('58430c314d992d1aec031bb4'),
#   u'advisories': [u'Infrequent/Mild Alcohol, Tobacco, or Drug Use or References',
#                   u'Infrequent/Mild Sexual Content and Nudity',
#                   u'Infrequent/Mild Profanity or Crude Humor'],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 441813335,
#   u'artistName': u'Saavn',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.0,
#   u'contentAdvisoryRating': u'12+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-02T22:00:29Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'47294464',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6011', u'6016'],
#   u'genres': [u'Music', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6011,
#   u'primaryGenreName': u'Music',
#   u'releaseDate': u'2011-06-08T23:33:30Z',
#   u'sellerName': u'Saavn',
#   u'sellerUrl': u'http://www.saavn.com/pro',
#   u'trackCensoredName': u'Saavn Music & Radio',
#   u'trackContentRating': u'12+',
#   u'trackId': 441813332,
#   u'trackName': u'Saavn Music & Radio',
#   u'userRatingCount': 9795,
#   u'userRatingCountForCurrentVersion': 46,
#   u'version': u'5.3',
#   u'wrapperType': u'software'},
#  {u'Id': u'407558537',
#   u'_id': ObjectId('58430c314d992d1aec031bb6'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 339644101,
#   u'artistName': u'Capital One',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.5,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-15T18:07:42Z',
#   u'features': [],
#   u'fileSizeBytes': u'206390272',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6015'],
#   u'genres': [u'Finance'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6015,
#   u'primaryGenreName': u'Finance',
#   u'releaseDate': u'2010-12-13T08:00:00Z',
#   u'sellerName': u'Capital One Services, LLC',
#   u'sellerUrl': u'http://www.capitalone.com/online-banking/mobile/',
#   u'trackCensoredName': u'Capital One Mobile',
#   u'trackContentRating': u'4+',
#   u'trackId': 407558537,
#   u'trackName': u'Capital One Mobile',
#   u'userRatingCount': 50134,
#   u'userRatingCountForCurrentVersion': 678,
#   u'version': u'5.14.1',
#   u'wrapperType': u'software'},
#  {u'Id': u'296581815',
#   u'_id': ObjectId('58430c324d992d1aec031bb9'),
#   u'advisories': [],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 296581818,
#   u'artistName': u'OpenTable, Inc.',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.5,
#   u'contentAdvisoryRating': u'4+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-28T19:33:14Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'128059392',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6023', u'6003'],
#   u'genres': [u'Food & Drink', u'Travel'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'9.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6023,
#   u'primaryGenreName': u'Food & Drink',
#   u'releaseDate': u'2008-11-15T07:25:55Z',
#   u'sellerName': u'OpenTable, Inc.',
#   u'sellerUrl': u'http://www.opentable.com',
#   u'trackCensoredName': u'OpenTable - Restaurant Reservations',
#   u'trackContentRating': u'4+',
#   u'trackId': 296581815,
#   u'trackName': u'OpenTable - Restaurant Reservations',
#   u'userRatingCount': 105320,
#   u'userRatingCountForCurrentVersion': 195,
#   u'version': u'10.5.0',
#   u'wrapperType': u'software'},
#  {u'Id': u'372513032',
#   u'_id': ObjectId('58430c334d992d1aec031bbf'),
#   u'advisories': [u'Frequent/Intense Mature/Suggestive Themes'],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 372513035,
#   u'artistName': u'TangoMe, Inc.',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.5,
#   u'contentAdvisoryRating': u'17+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-11-23T20:16:53Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'127245312',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6005', u'6016'],
#   u'genres': [u'Social Networking', u'Entertainment'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'7.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6005,
#   u'primaryGenreName': u'Social Networking',
#   u'releaseDate': u'2010-09-30T00:44:30Z',
#   u'sellerName': u'TangoMe, Inc.',
#   u'sellerUrl': u'http://www.tango.me',
#   u'trackCensoredName': u'Tango - Free Video Call, Voice and Chat',
#   u'trackContentRating': u'17+',
#   u'trackId': 372513032,
#   u'trackName': u'Tango - Free Video Call, Voice and Chat',
#   u'userRatingCount': 74077,
#   u'userRatingCountForCurrentVersion': 93,
#   u'version': u'3.26.213361',
#   u'wrapperType': u'software'},
#  {u'Id': u'456034437',
#   u'_id': ObjectId('58430c334d992d1aec031bc1'),
#   u'advisories': [u'Infrequent/Mild Sexual Content and Nudity',
#                   u'Infrequent/Mild Profanity or Crude Humor',
#                   u'Infrequent/Mild Medical/Treatment Information',
#                   u'Infrequent/Mild Alcohol, Tobacco, or Drug Use or References',
#                   u'Infrequent/Mild Mature/Suggestive Themes'],
#   u'appletvScreenshotUrls': [],
#   u'artistId': 456034440,
#   u'artistName': u'Quora, Inc.',
#   u'averageUserRating': 4.5,
#   u'averageUserRatingForCurrentVersion': 4.5,
#   u'contentAdvisoryRating': u'12+',
#   u'currency': u'USD',
#   u'currentVersionReleaseDate': u'2016-12-01T19:30:16Z',
#   u'features': [u'iosUniversal'],
#   u'fileSizeBytes': u'33263616',
#   u'formattedPrice': u'Free',
#   u'genreIds': [u'6005', u'6006'],
#   u'genres': [u'Social Networking', u'Reference'],
#   u'kind': u'software',
#   u'minimumOsVersion': u'8.0',
#   u'price': 0.0,
#   u'primaryGenreId': 6005,
#   u'primaryGenreName': u'Social Networking',
#   u'releaseDate': u'2011-09-29T07:00:00Z',
#   u'sellerName': u'Quora, Inc',
#   u'trackCensoredName': u'Quora',
#   u'trackContentRating': u'12+',
#   u'trackId': 456034437,
#   u'trackName': u'Quora',
#   u'userRatingCount': 3748,
#   u'userRatingCountForCurrentVersion': 6,
#   u'version': u'5.1.0',
#   u'wrapperType': u'software'}]

# %%
# Sort by UserRatingCount
pprint.pprint(list(collection.find(
    {},{"artistName":1,"userRatingCount":1,"_id":0}
).sort("userRatingCount",-1)))

# %%
# Find the App with maximum userRatingCount
collection.find_one({}, {"artistName":1, "_id":0}, sort=[("userRatingCount",-1)])
